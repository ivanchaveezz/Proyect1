# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('universal_top_spotify_songs.csv')
country_danceability = data.groupby('country')['danceability'].mean().reset_index()
country_danceability = country_danceability.sort_values(by='danceability', ascending=False)

plt.figure(figsize=(20, 12))
plt.barh(country_danceability['country'], country_danceability['danceability'], color='skyblue')
plt.title('Danceability by Country')
plt.xlabel('Mean Danceability')
plt.ylabel('Country')

plt.show()

# %%
data = pd.read_csv('universal_top_spotify_songs.csv')
country_acousticness = data.groupby('country')['acousticness'].mean().reset_index()
country_acousticness = country_acousticness.sort_values(by='acousticness', ascending=False)

plt.figure(figsize=(20, 12))
plt.barh(country_acousticness['country'], country_acousticness['acousticness'], color='skyblue')
plt.title('Acousticness by Country')
plt.xlabel('Mean Acousticness')
plt.ylabel('Country')

plt.show()

# %%
data = pd.read_csv('universal_top_spotify_songs.csv')
country_loudness = data.groupby('country')['loudness'].mean().reset_index()
country_loudness = country_loudness.sort_values(by='loudness', ascending=False)

plt.figure(figsize=(20, 12))
plt.barh(country_loudness['country'], country_loudness['loudness'], color='skyblue')
plt.title('Loudsness by Country')
plt.xlabel('Mean Loudness')
plt.ylabel('Country')

plt.show()

# %%
data = pd.read_csv('universal_top_spotify_songs.csv')
country_instrumentalness = data.groupby('country')['instrumentalness'].mean().reset_index()
country_instrumentalness = country_instrumentalness.sort_values(by='instrumentalness', ascending=False)

plt.figure(figsize=(20, 12))
plt.barh(country_instrumentalness['country'], country_instrumentalness['instrumentalness'], color='skyblue')
plt.title('Instrumentalness by Country')
plt.xlabel('Mean Instrumentalness')
plt.ylabel('Country')

plt.show()
